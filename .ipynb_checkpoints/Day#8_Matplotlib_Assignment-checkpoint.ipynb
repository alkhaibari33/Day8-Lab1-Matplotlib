# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Q1: Create two charts using list and dataframe

# %%
plt.plot([1,2,0,4,5])
plt.plot(pd.DataFrame([9,5,3,7]))

# %% [markdown]
# ## Q2: Create pie chart with equal explode values.

# %%
plt.pie(np.arange(1,5), labels=['Jan','Feb','Mar', 'Apr'], explode = [.1,.2,.3,0]);

# %% [markdown]
# ## Q3: Create a scatter chart with circle marker, alpha = 0.4, and size = 50.

# %%
plt.scatter(x, y)
plt.scatter(x,y,alpha = 0.4)
plt.scatter(x, y, marker = '-', s= 50)
scatter

# %% [markdown]
# ## Q4: Add the following to your chart:
# - title placed in the left and has a red color
# - x and y label with font size = 16

# %%
plt.title('the title', fontsize = 16, loc='left', color='red');

# %% [markdown]
# ## Q5: Create three line charts with Legends at left and colors

# %%
plt.plot([1,2,0,4,5], '#4B0082')
plt.plot([10,9,8,6,3], c ='#029386')
plt.plot([12,13, 10, 20,13], color ='#A52A2A')

# %% [markdown]
# ## Q6: Create subplots with three charts and figsize=20,10

# %%
plt.figure(figsize=[20,10])
plt.suptitle('Subplots',fontsize = 15)

#1
plt.subplot(2,2,1) 
#plt.pie(np.arange(1,5),labels=['Jan','Feb','Mar']);
plt.title('Months')

#2
plt.subplot(2,2,2)
plt.plot([1,2,0,4,5])
plt.plot([10,9,8,6,3])
plt.legend(['2008','2009'], shadow = True, loc = 0)
plt.title('Years');
#3
plt.subplot(2,2,3) 
#plt.pie(np.arange(1,5),labels=['1','2','3']);
plt.title('numbers')
# Out:
# Text(0.5, 1.0, 'numbers')
